# %%
from datetime import datetime 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import ffn
import os
import path
# %matplotlib inline
plt.rcParams["figure.figsize"] = (10, 6) # (w, h)
#plt.ioff()

# %%
#tickers = ['VCB','BID','ACB','HDB','TPB','MBB','BAB','TCB','CTG','VPB','EIB','VIB','STB','KLB','NVB','LPB','SHB']
tickers = ['VCB','BID','ACB','HDB','TPB','MBB','TCB','CTG','VPB','EIB','STB']

# %%
available_sticker = [fileName.split('.')[0] for fileName in os.listdir('data/') if fileName.endswith('csv')]
download_sticker = [sticker for sticker in tickers if (sticker not in available_sticker)]
download_sticker
# Out:
# []

# %%
ticker = 'VCB'
df = pd.read_csv(f'data/{ticker}.csv')

# %%
#stocks = [pd.read_csv(f'data/{ticker}.csv',index_col='date',parse_dates=True)['adj_close'].rename(ticker) for ticker in tickers]
prices = (pd.concat(
    [pd.read_csv(f'data/{ticker}.csv',index_col='date',parse_dates=True)['adj_close'].rename(ticker) for ticker in tickers]
    ,axis=1,sort=True))

# %%
prices = prices[:'2020-10-16']
prices
# Out:
#               VCB    BID    ACB    HDB    TPB    MBB    TCB    CTG    VPB  \
# date
# 2016-01-04  30.05  17.97   9.22    NaN    NaN   8.54    NaN  16.93    NaN
# 2016-01-05  29.56  17.88   9.08    NaN    NaN   8.48    NaN  16.74    NaN
# 2016-01-06  29.91  17.97   9.12    NaN    NaN   8.54    NaN  16.93    NaN
# 2016-01-07  29.56  17.17   8.94    NaN    NaN   8.42    NaN  16.74    NaN
# 2016-01-08  29.35  16.72   8.94    NaN    NaN   8.36    NaN  16.37    NaN
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2020-10-12  85.90  40.95  23.30  24.35  24.80  17.55  21.20  29.10  23.40
# 2020-10-13  86.50  41.25  23.40  24.00  24.85  17.50  21.40  30.55  23.40
# 2020-10-14  88.20  42.90  24.00  24.25  25.00  17.65  22.85  30.00  24.00
# 2020-10-15  88.60  42.25  24.50  24.60  24.80  17.60  22.85  30.05  24.05
# 2020-10-16  88.20  42.20  24.70  24.80  24.95  17.85  22.65  31.15  24.60
#
#               EIB    STB
# date
# 2016-01-04  11.20  12.60
# 2016-01-05  11.20  12.30
# 2016-01-06  11.20  12.80
# 2016-01-07  11.10  12.60
# 2016-01-08  10.90  12.60
# ...           ...    ...
# 2020-10-12  17.20  13.30
# 2020-10-13  17.40  13.45
# 2020-10-14  17.40  13.50
# 2020-10-15  17.60  13.85
# 2020-10-16  17.35  13.75
#
# [1193 rows x 11 columns]

# %%
prices = prices.dropna()

# %%
from scipy.stats import linregress
def momentum(closes):
    returns = np.log(closes)
    x = np.arange(len(returns))
    slope, _, rvalue, _, _ = linregress(x, returns)
    return ((1 + slope) ** 252) * (rvalue ** 2)

# %%
momentums = prices.copy(deep=True)
for ticker in tickers:
    momentums[ticker] = prices[ticker].rolling(90).apply(momentum, raw=False)
momentums
# Out:
#                  VCB       BID       ACB       HDB       TPB       MBB  \
# date
# 2018-06-04       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-06-05       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-06-06       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-06-07       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-06-08       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2020-10-12  0.004363  0.033992  1.121015  0.809190  0.500072  0.191286
# 2020-10-13  0.006474  0.033441  1.140706  0.809551  0.552018  0.218387
# 2020-10-14  0.006386  0.025196  1.172643  0.815957  0.622775  0.254812
# 2020-10-15  0.005350  0.020616  1.207425  0.823148  0.692363  0.289567
# 2020-10-16  0.003398  0.015196  1.247403  0.858420  0.759615  0.335681
#
#                  TCB       CTG       VPB       EIB       STB
# date
# 2018-06-04       NaN       NaN       NaN       NaN       NaN
# 2018-06-05       NaN       NaN       NaN       NaN       NaN
# 2018-06-06       NaN       NaN       NaN       NaN       NaN
# 2018-06-07       NaN       NaN       NaN       NaN       NaN
# 2018-06-08       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...
# 2020-10-12  0.009906  0.517242  0.036788  0.073071  0.529347
# 2020-10-13  0.013234  0.541527  0.022765  0.119219  0.535960
# 2020-10-14  0.027436  0.583166  0.009809  0.156337  0.546715
# 2020-10-15  0.044183  0.625850  0.002362  0.192108  0.578710
# 2020-10-16  0.073161  0.686673  0.000187  0.189753  0.611975
#
# [581 rows x 11 columns]

# %%
stocks = prices['2020-01-01':]

# %%
plt.figure(figsize=(12, 9))
plt.xlabel('Days')
plt.ylabel('Stock Price')

bests = momentums.max().sort_values(ascending=False).index[:7]
bests
#bests = ['HDB', 'EIB', 'VCB', 'STB']
# Out:
# Index(['BID', 'HDB', 'EIB', 'VCB', 'STB', 'TCB', 'CTG'], dtype='object')

# %%
for best in bests:
    end = momentums[best].index.get_loc(momentums[best].idxmax())
    rets = np.log(stocks[best].iloc[end - 90 : end])
    x = np.arange(len(rets))
    slope, intercept, r_value, p_value, std_err = linregress(x, rets)
    plt.plot(np.arange(len(stocks[best][end-90:end+90])), stocks[best][end-90:end+90])
    plt.plot(x, np.e ** (intercept + slope*x))
    plt.legend(bests,loc = 'upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-62ebad2d60a6> in <module>
#       3     rets = np.log(stocks[best].iloc[end - 90 : end])
#       4     x = np.arange(len(rets))
# ----> 5     slope, intercept, r_value, p_value, std_err = linregress(x, rets)
#       6     plt.plot(np.arange(len(stocks[best][end-90:end+90])), stocks[best][end-90:end+90])
#       7     plt.plot(x, np.e ** (intercept + slope*x))
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/stats/_stats_mstats_common.py in linregress(x, y)
#     107
#     108     if x.size == 0 or y.size == 0:
# --> 109         raise ValueError("Inputs must not be empty.")
#     110
#     111     n = len(x)
#
# ValueError: Inputs must not be empty.

# %%
prices = prices['2020-01-01':].dropna()
prices.rebase().plot()

# %%
perf.set_riskfree_rate(0.05)
perf = prices.calc_stats()
# Out:
# /Users/nhacheat/anaconda3/lib/python3.8/site-packages/ffn/core.py:2056: RuntimeWarning: divide by zero encountered in true_divide
#   res = np.divide(er.mean(), std)

# %%
perf['VCB'].display()
# Out:
# Stats for VCB from 2018-06-04 00:00:00 - 2020-10-16 00:00:00
# Annual risk-free rate considered: 0.00%
# Summary:
# Total Return      Sharpe  CAGR    Max Drawdown
# --------------  --------  ------  --------------
# 51.99%              0.79  19.34%  -39.47%
#
# Annualized Returns:
# mtd    3m     6m      ytd     1y     3y      5y    10y    incep.
# -----  -----  ------  ------  -----  ------  ----  -----  --------
# 4.88%  5.63%  23.88%  -2.22%  3.35%  19.34%  -     -      19.34%
#
# Periodic:
#         daily    monthly    yearly
# ------  -------  ---------  --------
# sharpe  0.79     0.76       0.66
# mean    22.12%   23.80%     33.94%
# vol     28.02%   31.13%     51.13%
# skew    -0.23    -0.37      -
# kurt    2.69     2.88       -
# best    6.90%    25.29%     70.09%
# worst   -6.99%   -24.76%    -2.22%
#
# Drawdowns:
# max      avg       # days
# -------  ------  --------
# -39.47%  -5.02%     28.61
#
# Misc:
# ---------------  ------
# avg. up month    7.11%
# avg. down month  -5.95%
# up year %        50.00%
# 12m up %         83.33%
# ---------------  ------
